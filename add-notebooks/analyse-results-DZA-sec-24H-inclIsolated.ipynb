# %% [markdown]
# # Analyse results from Pypsa-Earth

# %% [markdown]
# DOES NOT WORK with Sector-Scoupled Networks !

# %% [markdown]
# Sources:
# - Plot capacity - map view: https://github.com/pypsa-meets-earth/documentation/blob/main/notebooks/viz/regional_transm_system_viz.ipynb
# - Analyse energy potential: https://github.com/pypsa-meets-earth/documentation/blob/main/notebooks/build_renewable_profiles.ipynb
# - Analyse energy generation: https://pypsa.readthedocs.io/en/latest/examples/statistics.html

# %% [markdown]
# Some files are needed:
# * PyPSA network file (e.g. "elec.nc" contains a lot of details and looks perfect)
# * a country shape file (may be found in "resources/shapes/country_shapes.geojson")
# * a renewable profile file (may be found in "resources/renewable_profiles/....nc)

# %% [markdown]
# ## Own setting

# %%
import os
import sys
import yaml

PARENT = os.path.realpath("../../pypsa-earth") + "/"
# config = yaml.safe_load(open(PARENT + "config-2030-NetZero-3TWh-Hydro.yaml"))
config = yaml.safe_load(open(PARENT + "config-2030-DZ-InclIsolated-GADM-sec-NetZero.yaml"))

# Read config.yaml settings:
name = config["run"]["name"]
simpl = config["scenario"]["simpl"]
# clusters = "10"
clusters = config["scenario"]["clusters"]
ll = config["scenario"]["ll"]
opts = config["scenario"]["opts"]

# Ensure elements are strings and properly joined
simpl_str = "_".join(map(str, simpl))
clusters_str = "_".join(map(str, clusters))
#clusters_str = clusters
ll_str = "_".join(map(str, ll))
opts_str = "_".join(map(str, opts))
export = "1"
geothermal_potential = "3"

# %% [markdown]
# ## Import packages

# %%
import yaml
import pypsa
import warnings
import matplotlib.pyplot as plt
import geopandas as gpd
import numpy as np
import pandas as pd
from pathlib import Path
import seaborn as sns
from datetime import datetime
from cartopy import crs as ccrs
from pypsa.plot import add_legend_circles, add_legend_lines, add_legend_patches
import os
import xarray as xr
import cartopy

# %% [markdown]
# ## Path settings

# %%
# nc_file_name = f"elec_s{simpl_str}_{clusters_str}_ec_l{ll_str}_{opts_str}-{export}-{geothermal_potential}.nc"
nc_file_name = f"elec_s{simpl_str}_{clusters_str}_ec_l{ll_str}_{opts_str}.nc"
scenario_name = name 
scenario_subpath = scenario_name + "/" if scenario_name else ""

# Network file
#results_path = PARENT + f"results/{scenario_subpath}networks/{nc_file_name}"
results_path = PARENT + f"results/DZA-1/postnetworks/elec_s_48_ec_lcopt_Co2L-24H_24H_2030_0.071_AB_10export.nc"
network_path = PARENT + f"networks/{scenario_subpath}elec.nc"
# Country shape file
regions_onshore_path = PARENT + f"resources/{scenario_subpath}shapes/country_shapes.geojson"
# Renewable profile file
solar_path = PARENT + f"resources/{scenario_subpath}renewable_profiles/profile_solar.nc"
onwind_path = PARENT + f"resources/{scenario_subpath}renewable_profiles/profile_onwind.nc"

# %% [markdown]
# ## Energy system analysis setup - power and energy generation

# %%
warnings.simplefilter(action='ignore', category=FutureWarning)
n = pypsa.Network(results_path)
regions_onshore = gpd.read_file(regions_onshore_path)
country_coordinates = regions_onshore.total_bounds[[0, 2, 1, 3]]
warnings.simplefilter(action='default', category=FutureWarning)
# Out:
# INFO:pypsa.io:Imported network elec_s_48_ec_lcopt_Co2L-24H_24H_2030_0.071_AB_10export.nc has buses, carriers, generators, global_constraints, lines, links, loads, storage_units, stores

# %% [markdown]
# ## Data import check

# %% [markdown]
# Country check

# %%
fig, ax = plt.subplots(figsize=(8, 8), subplot_kw={"projection": ccrs.EqualEarth(n.buses.x.mean())})
with plt.rc_context({"patch.linewidth": 0.}):
    regions_onshore.plot(
    ax=ax,
    facecolor="green",
    edgecolor="white",
    aspect="equal",
    transform=ccrs.PlateCarree(),
    linewidth=0,
    )
ax.set_title(", ".join(regions_onshore.name.values))
# Out:
# Text(0.5, 1.0, 'DZ')

# %% [markdown]
# Component check

# %%
for c in n.iterate_components(list(n.components.keys())[2:]):
    print("Component '{}' has {} entries".format(c.name,len(c.df)))
# Out:
# Component 'Bus' has 1132 entries
# Component 'Carrier' has 38 entries
# Component 'GlobalConstraint' has 1 entries
# Component 'Line' has 96 entries
# Component 'LineType' has 34 entries
# Component 'TransformerType' has 14 entries
# Component 'Link' has 3115 entries
# Component 'Load' has 1421 entries
# Component 'Generator' has 1725 entries
# Component 'StorageUnit' has 1 entries
# Component 'Store' has 755 entries

# %%
buses = n.buses.loc[n.buses['carrier']=='AC']
buses_geo = gpd.points_from_xy(buses["lon"], buses["lat"])
buses_gdf = gpd.GeoDataFrame(buses, geometry=buses_geo, crs=4326)

# %%
buses_gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_94869c1e8ea2350c068e801ef86ad819 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_94869c1e8ea2350c068e801ef86ad819&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_94869c1e8ea2350c068e801ef86ad819 = L.map(
#                 &quot;map_94869c1e8ea2350c068e801ef86ad819&quot;,
#                 {
#                     center: [32.13705, 3.421966666666666],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_94869c1e8ea2350c068e801ef86ad819);
#
#
#
#
#
#             var tile_layer_d63a50b6bea34529636700d9adf2c5ce = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d63a50b6bea34529636700d9adf2c5ce.addTo(map_94869c1e8ea2350c068e801ef86ad819);
#
#
#             map_94869c1e8ea2350c068e801ef86ad819.fitBounds(
#                 [[27.47535, -1.7639666666666667], [36.798750000000005, 8.607899999999999]],
#                 {}
#             );
#
#
#         function geo_json_a39a385659aa564a0b5e52fe3794de02_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_a39a385659aa564a0b5e52fe3794de02_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_a39a385659aa564a0b5e52fe3794de02_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_a39a385659aa564a0b5e52fe3794de02_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_a39a385659aa564a0b5e52fe3794de02_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_a39a385659aa564a0b5e52fe3794de02.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_a39a385659aa564a0b5e52fe3794de02_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_a39a385659aa564a0b5e52fe3794de02 = L.geoJson(null, {
#                 onEachFeature: geo_json_a39a385659aa564a0b5e52fe3794de02_onEachFeature,
#
#                 style: geo_json_a39a385659aa564a0b5e52fe3794de02_styler,
#                 pointToLayer: geo_json_a39a385659aa564a0b5e52fe3794de02_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_a39a385659aa564a0b5e52fe3794de02_add (data) {
#             geo_json_a39a385659aa564a0b5e52fe3794de02
#                 .addData(data);
#         }
#             geo_json_a39a385659aa564a0b5e52fe3794de02_add({&quot;bbox&quot;: [-1.7639666666666667, 27.47535, 8.607899999999999, 36.798750000000005], &quot;features&quot;: [{&quot;bbox&quot;: [2.8330333333333333, 36.50841111111111, 2.8330333333333333, 36.50841111111111], &quot;geometry&quot;: {&quot;coordinates&quot;: [2.8330333333333333, 36.50841111111111], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;Bus&quot;: &quot;DZ.10_1_AC&quot;, &quot;carrier&quot;: &quot;AC&quot;, &quot;control&quot;: &quot;Slack&quot;, &quot;country&quot;: &quot;DZ&quot;, &quot;gadm_1&quot;: &quot;DZ.10_1&quot;, &quot;gadm_subnetwork&quot;: &quot;DZ.10_1_AC&quot;, &quot;generator&quot;: &quot;DZ.10_1_AC CCGT&quot;, &quot;lat&quot;: 36.5084111

# %% [markdown]
# Snapshot check

# %%
print(n.snapshots)
print(f"Time steps: " + str(len(n.snapshots)))
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06', '2013-01-07', '2013-01-08',
#                '2013-01-09', '2013-01-10',
#                ...
#                '2013-12-22', '2013-12-23', '2013-12-24', '2013-12-25',
#                '2013-12-26', '2013-12-27', '2013-12-28', '2013-12-29',
#                '2013-12-30', '2013-12-31'],
#               dtype='datetime64[ns]', name='snapshot', length=365, freq=None)
# Time steps: 365

# %% [markdown]
# ## Analyse energy system

# %% [markdown]
# Analyse the current capacity of the energy system - map view

# %%
# Scale settings
bus_scale = 3e3 
line_scale = 2e3

# Legend settings
bus_sizes = [100, 1000]  # in MW
line_sizes = [100, 1000]  # in MW

# n-noLoad = n.carriers.drop("Load", inplace=False)
n.carriers.drop("Load", inplace=True)

fig, ax = plt.subplots(figsize=(8, 8), subplot_kw={"projection": ccrs.EqualEarth(n.buses.x.mean())})
gen = n.generators[(n.generators.carrier != "load") & (n.generators.carrier != "export")].groupby(["bus", "carrier"]).p_nom.sum()
sto = n.storage_units.groupby(["bus", "carrier"]).p_nom.sum()
buses = pd.concat([gen, sto])

with plt.rc_context({"patch.linewidth": 0.}):
    n.plot(
        bus_sizes=buses / bus_scale,
        bus_alpha=0.7,
        line_widths=n.lines.s_nom_opt / line_scale,
        link_widths=n.links[n.links.carrier != "export"].p_nom_opt / line_scale,
        line_colors="teal",
        ax=ax,
        margin=0.1,
        color_geomap=None,
    )
regions_onshore.plot(
    ax=ax,
    facecolor="whitesmoke",
    edgecolor="white",
    aspect="equal",
    transform=ccrs.PlateCarree(),
    linewidth=0,
)
ax.set_extent(regions_onshore.total_bounds[[0, 2, 1, 3]])

# Make more space at bottom to not cut off capacity circle
ylims = ax.get_ylim()  # Get current y-axis limits
ax.set_ylim(ylims[0] - 1e5, ylims[1] + 1e5)  # Extend the bottom and top by shifting downward + upward

legend_kwargs = {"loc": "upper left", "frameon": False}
legend_circles_dict = {"bbox_to_anchor": (1, 0.67), "labelspacing": 2.5, **legend_kwargs}

add_legend_circles(
    ax,
    [s / bus_scale for s in bus_sizes],
    [f"{s / 1000} GW" for s in bus_sizes],
    legend_kw=legend_circles_dict,    
)
add_legend_lines(
    ax,
    [s / line_scale for s in line_sizes],
    [f"{s / 1000} GW" for s in line_sizes],
    legend_kw={"bbox_to_anchor": (1, 0.8), **legend_kwargs},
)
add_legend_patches(
    ax,
    n.carriers.color,
    n.carriers.nice_name,
    legend_kw={"bbox_to_anchor": (1, 0), **legend_kwargs, "loc":"lower left"},
)
fig.tight_layout()
fig.savefig("brownfield_capacities_" + scenario_name + ".png", bbox_inches="tight", dpi=300)
# Out:
# /home/marco-s/miniconda3/envs/pypsa-earth-2/lib/python3.10/site-packages/cartopy/mpl/feature_artist.py:144: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[15], line 18
#      15 buses = pd.concat([gen, sto])
#      17 with plt.rc_context({"patch.linewidth": 0.}):
# ---> 18     n.plot(
#      19         bus_sizes=buses / bus_scale,
#      20         bus_alpha=0.7,
#      21         line_widths=n.lines.s_nom_opt / line_scale,
#      22         link_widths=n.links[n.links.carrier != "export"].p_nom_opt / line_scale,
#      23         line_colors="teal",
#      24         ax=ax,
#      25         margin=0.1,
#      26         color_geomap=None,
#      27     )
#      28 regions_onshore.plot(
#      29     ax=ax,
#      30     facecolor="whitesmoke",
#    (...)
#      34     linewidth=0,
#      35 )
#      36 ax.set_extent(regions_onshore.total_bounds[[0, 2, 1, 3]])
#
# File ~/miniconda3/envs/pypsa-earth-2/lib/python3.10/site-packages/pypsa/plot.py:270, in plot(n, margin, ax, geomap, projection, bus_colors, bus_alpha, bus_sizes, bus_cmap, bus_norm, bus_split_circles, line_colors, link_colors, transformer_colors, line_alpha, link_alpha, transformer_alpha, line_widths, link_widths, transformer_widths, line_cmap, link_cmap, transformer_cmap, line_norm, link_norm, transformer_norm, flow, branch_components, layouter, title, boundaries, geometry, jitter, color_geomap)
#     268 if not isinstance(bus_colors, pd.Series):
#     269     bus_colors = n.carriers.color.dropna()
# --> 270 assert bus_sizes.index.unique(level=1).isin(bus_colors.index).all(), (
#     271     "Colors not defined for all elements in the second MultiIndex "
#     272     "level of bus_sizes, please make sure that all the elements are "
#     273     "included in bus_colors or in n.carriers.color"
#     274 )
#     276 bus_sizes = bus_sizes.sort_index(level=0, sort_remaining=False)
#     277 if geomap:
#
# AssertionError: Colors not defined for all elements in the second MultiIndex level of bus_sizes, please make sure that all the elements are included in bus_colors or in n.carriers.color

# %% [markdown]
# Analyse the current generation capacity of the energy system - pie chart view

# %%
generator_capacity_by_carrier = n.generators[(n.generators.carrier != "load") & (n.generators.carrier != "export")].groupby(["carrier"]).p_nom.sum()
plt.figure(figsize=(8, 8))
plt.pie(generator_capacity_by_carrier, labels=generator_capacity_by_carrier.index, autopct='%1.1f%%', colors=n.carriers[n.carriers.index.isin(generator_capacity_by_carrier.index)].color.reindex(generator_capacity_by_carrier.index))
plt.title("Generator Capacity by Carrier")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 3
#       1 generator_capacity_by_carrier = n.generators[(n.generators.carrier != "load") & (n.generators.carrier != "export")].groupby(["carrier"]).p_nom.sum()
#       2 plt.figure(figsize=(8, 8))
# ----> 3 plt.pie(generator_capacity_by_carrier, labels=generator_capacity_by_carrier.index, autopct='%1.1f%%', colors=n.carriers[n.carriers.index.isin(generator_capacity_by_carrier.index)].color.reindex(generator_capacity_by_carrier.index))
#       4 plt.title("Generator Capacity by Carrier")
#
# File ~/miniconda3/envs/pypsa-earth-2/lib/python3.10/site-packages/matplotlib/pyplot.py:2756, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, data)
#    2749 @_copy_docstring_and_deprecators(Axes.pie)
#    2750 def pie(
#    2751         x, explode=None, labels=None, colors=None, autopct=None,
#    (...)
#    2754         textprops=None, center=(0, 0), frame=False,
#    2755         rotatelabels=False, *, normalize=True, data=None):
# -> 2756     return gca().pie(
#    2757         x, explode=explode, labels=labels, colors=colors,
#    2758         autopct=autopct, pctdistance=pctdistance, shadow=shadow,
#    2759         labeldistance=labeldistance, startangle=startangle,
#    2760         radius=radius, counterclock=counterclock,
#    2761         wedgeprops=wedgeprops, textprops=textprops, center=center,
#    2762         frame=frame, rotatelabels=rotatelabels, normalize=normalize,
#    2763         **({"data": data} if data is not None else {}))
#
# File ~/miniconda3/envs/pypsa-earth-2/lib/python3.10/site-packages/matplotlib/__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File ~/miniconda3/envs/pypsa-earth-2/lib/python3.10/site-packages/matplotlib/axes/_axes.py:3092, in Axes.pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize)
#    3089 x += expl * math.cos(thetam)
#    3090 y += expl * math.sin(thetam)
# -> 3092 w = mpatches.Wedge((x, y), radius, 360. * min(theta1, theta2),
#    3093                    360. * max(theta1, theta2),
#    3094                    facecolor=get_next_color(),
#    3095                    clip_on=False,
#    3096                    label=label)
#    3097 w.set(**wedgeprops)
#    3098 slices.append(w)
#
# File ~/miniconda3/envs/pypsa-earth-2/lib/python3.10/site-packages/matplotlib/patches.py:1159, in Wedge.__init__(self, center, r, theta1, theta2, width, **kwargs)
#    1147 @docstring.dedent_interpd
#    1148 def __init__(self, center, r, theta1, theta2, width=None, **kwargs):
#    1149     """
#    1150     A wedge centered at *x*, *y* center with radius *r* that
#    1151     sweeps *theta1* to *theta2* (in degrees).  If *width* is given,
#    (...)
#    1157     %(Patch:kwdoc)s
#    1158     """
# -> 1159     super().__init__(**kwargs)
#    1160     self.center = center
#    1161     self.r, self.width = r, width
#
# File ~/miniconda3/envs/pypsa-earth-2/lib/python3.10/site-packages/matplotlib/patches.py:99, in Patch.__init__(self, edgecolor, facecolor, color, linewidth, linestyle, antialiased, hatch, fill, capstyle, joinstyle, **kwargs)
#      97 else:
#      98     self.set_edgecolor(edgecolor)
# ---> 99     self.set_facecolor(facecolor)
#     100 # unscaled dashes.  Needed to scale dash patterns by lw
#     101 self._us_dashes = None
#
# File ~/miniconda3/envs/pypsa-earth-2/lib/python3.10/site-packages/matplotlib/patches.py:373, in Patch.set_facecolor(self, color)
#     365 """
#     366 Set the patch face color.
#     367
#    (...)
#     370 color : color or None
#     371 """
#     372 self._original_facecolor = color
# --> 373 self._set_facecolor(color)
#
# File ~/miniconda3/envs/pypsa-earth-2/lib/python3.10/site-packages/matplotlib/patches.py:361, in Patch._set_facecolor(self, color)
#     359     color = mpl.rcParams['patch.facecolor']
#     360 alpha = self._alpha if self._fill else 0
# --> 361 self._facecolor = colors.to_rgba(color, alpha)
#     362 self.stale = True
#
# File ~/miniconda3/envs/pypsa-earth-2/lib/python3.10/site-packages/matplotlib/colors.py:187, in to_rgba(c, alpha)
#     185     rgba = None
#     186 if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 187     rgba = _to_rgba_no_colorcycle(c, alpha)
#     188     try:
#     189         _colors_full_map.cache[c, alpha] = rgba
#
# File ~/miniconda3/envs/pypsa-earth-2/lib/python3.10/site-packages/matplotlib/colors.py:262, in _to_rgba_no_colorcycle(c, alpha)
#     258             raise ValueError(
#     259                 f"Invalid string grayscale value {orig_c!r}. "
#     260                 f"Value must be within 0-1 range")
#     261         return c, c, c, alpha if alpha is not None else 1.
# --> 262     raise ValueError(f"Invalid RGBA argument: {orig_c!r}")
#     263 # turn 2-D array into 1-D array
#     264 if isinstance(c, np.ndarray):
#
# ValueError: Invalid RGBA argument: ''

# %% [markdown]
# Analyse the current gernation capacity of the energy system - tabular view

# %%
generator_capacity_by_carrier/1e3 # in GW
# Out:
# carrier
# CCGT          29.635056
# offwind-ac     0.000000
# offwind-dc     0.000000
# oil            1.176446
# onwind         0.009506
# ror            0.021378
# solar          0.425800
# Name: p_nom, dtype: float64

# %% [markdown]
# Analyse the future capacity of the energy system - map view

# %%
bus_scale = 3e3 
line_scale = 2e3

fig, ax = plt.subplots(figsize=(8, 8), subplot_kw={"projection": ccrs.EqualEarth(n.buses.x.mean())})
gen = n.generators[(n.generators.carrier != "load") & (n.generators.carrier != "export")].groupby(["bus", "carrier"]).p_nom_opt.sum()
sto = n.storage_units.groupby(["bus", "carrier"]).p_nom_opt.sum()
buses = pd.concat([gen, sto])

with plt.rc_context({"patch.linewidth": 0.}):
    n.plot(
        bus_sizes=buses / bus_scale,
        bus_alpha=0.7,
        line_widths=n.lines.s_nom_opt / line_scale,
        link_widths=n.links[n.links.carrier != "export"].p_nom_opt / line_scale,
        line_colors="teal",
        ax=ax,
        margin=0.2,
        color_geomap=None,
    )
regions_onshore.plot(
    ax=ax,
    facecolor="whitesmoke",
    edgecolor="white",
    aspect="equal",
    transform=ccrs.PlateCarree(),
    linewidth=0,
)
ax.set_extent(regions_onshore.total_bounds[[0, 2, 1, 3]])

# Make more space at bottom to not cut off capacity circle
ylims = ax.get_ylim()  # Get current y-axis limits
ax.set_ylim(ylims[0] - 0.7e5, ylims[1] + 0.7e5)  # Extend the bottom by shifting downward

legend_kwargs = {"loc": "upper left", "frameon": False}
legend_circles_dict = {"bbox_to_anchor": (1, 0.67), "labelspacing": 2.5, **legend_kwargs}

add_legend_circles(
    ax,
    [s / bus_scale for s in bus_sizes],
    [f"{s / 1000} GW" for s in bus_sizes],
    legend_kw=legend_circles_dict,    
)
add_legend_lines(
    ax,
    [s / line_scale for s in line_sizes],
    [f"{s / 1000} GW" for s in line_sizes],
    legend_kw={"bbox_to_anchor": (1, 0.8), **legend_kwargs},
)
add_legend_patches(
    ax,
    n.carriers.color,
    n.carriers.nice_name,
    legend_kw={"bbox_to_anchor": (1, 0), **legend_kwargs, "loc":"lower left"},
)
fig.tight_layout()
# Out:
# /home/marco-s/miniconda3/envs/pypsa-earth-2/lib/python3.10/site-packages/cartopy/mpl/feature_artist.py:144: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[17], line 10
#       7 buses = pd.concat([gen, sto])
#       9 with plt.rc_context({"patch.linewidth": 0.}):
# ---> 10     n.plot(
#      11         bus_sizes=buses / bus_scale,
#      12         bus_alpha=0.7,
#      13         line_widths=n.lines.s_nom_opt / line_scale,
#      14         link_widths=n.links[n.links.carrier != "export"].p_nom_opt / line_scale,
#      15         line_colors="teal",
#      16         ax=ax,
#      17         margin=0.2,
#      18         color_geomap=None,
#      19     )
#      20 regions_onshore.plot(
#      21     ax=ax,
#      22     facecolor="whitesmoke",
#    (...)
#      26     linewidth=0,
#      27 )
#      28 ax.set_extent(regions_onshore.total_bounds[[0, 2, 1, 3]])
#
# File ~/miniconda3/envs/pypsa-earth-2/lib/python3.10/site-packages/pypsa/plot.py:270, in plot(n, margin, ax, geomap, projection, bus_colors, bus_alpha, bus_sizes, bus_cmap, bus_norm, bus_split_circles, line_colors, link_colors, transformer_colors, line_alpha, link_alpha, transformer_alpha, line_widths, link_widths, transformer_widths, line_cmap, link_cmap, transformer_cmap, line_norm, link_norm, transformer_norm, flow, branch_components, layouter, title, boundaries, geometry, jitter, color_geomap)
#     268 if not isinstance(bus_colors, pd.Series):
#     269     bus_colors = n.carriers.color.dropna()
# --> 270 assert bus_sizes.index.unique(level=1).isin(bus_colors.index).all(), (
#     271     "Colors not defined for all elements in the second MultiIndex "
#     272     "level of bus_sizes, please make sure that all the elements are "
#     273     "included in bus_colors or in n.carriers.color"
#     274 )
#     276 bus_sizes = bus_sizes.sort_index(level=0, sort_remaining=False)
#     277 if geomap:
#
# AssertionError: Colors not defined for all elements in the second MultiIndex level of bus_sizes, please make sure that all the elements are included in bus_colors or in n.carriers.color

# %% [markdown]
# Calculate emissions of future energy system

# %%
#ToDo: Not fully correct - double check
co2_emissions = pd.DataFrame(data=n.carriers[["co2_emissions", "nice_name"]]).set_index("nice_name").squeeze().rename_axis("carrier")

energy_production = n.statistics.energy_balance().Generator.droplevel(1).drop(["load", "export"], errors="ignore")

co2_emissions_technology = energy_production * co2_emissions.loc[energy_production.index] * n.snapshot_weightings.generators[0]
co2_emissions_technology
# Out:
# /tmp/ipykernel_20340/272665663.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   co2_emissions_technology = energy_production * co2_emissions.loc[energy_production.index] * n.snapshot_weightings.generators[0]
# carrier
# Offshore Wind (AC)    0.0
# Onshore Wind          0.0
# Run of River          0.0
# Solar                 0.0
# dtype: float64

# %%
co2_emissions_sum = co2_emissions_technology.sum()
co2_emissions_sum
# Out:
# 0.0

# %%
n.global_constraints
# Out:
#                  sense            mu            type  investment_period  \
# GlobalConstraint
# CO2Limit            <= -10514.356146  primary_energy                NaN
#
#                  carrier_attribute  constant
# GlobalConstraint
# CO2Limit             co2_emissions       0.0

# %%
# Step 1: Create the links_energy DataFrame with "carrier" and "bus0" columns
links_energy = n.links[["carrier", "bus0"]]

# Step 2: Filter only rows where "carrier" contains 'export'
links_energy = links_energy[links_energy["carrier"].str.contains("export", case=False, na=False)]

# Step 3: Calculate the energy sum for indices that contain 'export'
export_energy = n.links_t.p0.sum()
export_energy = export_energy[export_energy.index.str.contains("export", case=False, na=False)]

# Step 4: Map the energy sum to the correct rows in links_energy based on the index
links_energy["energy"] = links_energy.index.map(export_energy)

# Step 5: Group by "bus0" and "carrier" and sum the "energy" values
links_energy_grouped = links_energy.groupby(["bus0", "carrier"], as_index=False)["energy"].sum()

# Display the result
links_energy_grouped
# Out:
# Empty DataFrame
# Columns: [bus0, carrier, energy]
# Index: []

# %% [markdown]
# Analys the future generation capacity expansion of the energy system - bar chart

# %%
generation_capacity_expansion = n.statistics.optimal_capacity(comps=["Generator"]).droplevel(0).div(1e3)-n.statistics.installed_capacity(comps=["Generator"]).droplevel(0).div(1e3)
generation_capacity_expansion
# Out:
# carrier
# Combined-Cycle Gas     0.000000
# Offshore Wind (AC)          NaN
# Oil                    0.000000
# Onshore Wind           1.807775
# Run of River           0.000000
# Solar                 71.238540
# load                   0.000000
# dtype: float64

# %% [markdown]
# Plot the future generation capacity expansion of the energy system - tabular chart

# %%
generation_capacity_expansion = n.statistics.optimal_capacity(comps=["Generator"]).droplevel(0).div(1e3)-n.statistics.installed_capacity(comps=["Generator"]).droplevel(0).div(1e3)
generation_capacity_expansion.plot.bar(title="Generator capacity expansion in GW")
# Out:
# <AxesSubplot:title={'center':'Generator capacity expansion in GW'}, xlabel='carrier'>

# %% [markdown]
# Analyse the future energy generation of the energy system - bar chart view

# %%
fig, ax = plt.subplots()
color_setting = n.carriers.set_index(n.carriers.nice_name)
energy_balance = n.statistics.energy_balance().loc[:, :, "AC"].groupby("carrier").sum().div(1e6).to_frame().T
energy_balance.plot.bar(stacked=True, ax=ax, title="Energy Balance in TWh")
n.carriers[n.carriers.index.isin(generator_capacity_by_carrier.index)].color.reindex(generator_capacity_by_carrier.index)

ax.legend(bbox_to_anchor=(1, 0), loc="lower left", title=None, ncol=1)

# %%
n.statistics.energy_balance()
# Out:
# component    carrier             bus_carrier
# Link         H2 electrolysis     AC            -1.838293e+06
#              H2 fuel cell        H2            -1.470634e+06
#              battery charger     AC            -5.213015e+02
#              battery discharger  battery       -4.691805e+02
#              H2 electrolysis     H2             1.470634e+06
#              H2 fuel cell        AC             8.529678e+05
#              battery charger     battery        4.691713e+02
#              battery discharger  AC             4.222624e+02
# Store        Battery Storage     battery       -6.921547e-16
#              Hydrogen Storage    H2            -3.704477e-10
# Generator    Offshore Wind (AC)  AC             3.020358e-02
#              Onshore Wind        AC             1.648067e+06
#              Run of River        AC             1.867523e+05
#              Solar               AC             1.030441e+08
# StorageUnit  Reservoir & Dam     AC             1.221527e+05
# Load         -                   AC            -1.040156e+08
# dtype: float64

# %% [markdown]
# Analyse the future energy generation of the energy system - tabular view

# %%
n.statistics.energy_balance()/1e6 # In TWh
# Out:
# component    carrier             bus_carrier
# Link         H2 electrolysis     AC            -1.838293e+00
#              H2 fuel cell        H2            -1.470634e+00
#              battery charger     AC            -5.213015e-04
#              battery discharger  battery       -4.691805e-04
#              H2 electrolysis     H2             1.470634e+00
#              H2 fuel cell        AC             8.529678e-01
#              battery charger     battery        4.691713e-04
#              battery discharger  AC             4.222624e-04
# Store        Battery Storage     battery       -6.921547e-22
#              Hydrogen Storage    H2            -3.704477e-16
# Generator    Offshore Wind (AC)  AC             3.020358e-08
#              Onshore Wind        AC             1.648067e+00
#              Run of River        AC             1.867523e-01
#              Solar               AC             1.030441e+02
#              load                AC             1.300899e-08
#                                  H2             1.299672e-08
#                                  battery        1.298075e-08
# StorageUnit  Reservoir & Dam     AC             1.221527e-01
# Load         -                   AC            -1.040156e+02
# dtype: float64

# %% [markdown]
# ## Analyse pv and wind potential - map view

# %%
solar = xr.open_dataset(solar_path)
wind = xr.open_dataset(onwind_path)

def plot_voronoi(n, carrier, voronoi, cmap, projection, title=None, filename=None):
    g = n.generators.loc[n.generators.carrier == carrier]
    # br = gpd.read_file(f"resources/{scenario_name}/bus_regions/regions_{voronoi}.geojson").set_index("name")
    br = gpd.read_file(PARENT + f"resources/{scenario_name}/bus_regions/regions_{voronoi}.geojson").set_index("name")
    br_area = br.to_crs("ESRI:54009")
    br_area = br_area.geometry.area * 1e-6
    br["p_nom_max"] = g.groupby("bus").sum().p_nom_max / br_area

    fig, ax = plt.subplots(figsize=(8, 4), subplot_kw={"projection": projection})
    plt.rcParams.update({"font.size": 10})
    br.plot(
        ax=ax,
        column="p_nom_max",
        transform=ccrs.PlateCarree(),
        linewidth=0.25,
        edgecolor="k",
        cmap=cmap,
        vmin=0,
        vmax=br["p_nom_max"].max(),
        legend=True,
        legend_kwds={"label": r"potential density"},
    )
    ax.coastlines()
    ax.add_feature(cartopy.feature.BORDERS.with_scale("110m"))
    ax.set_extent(country_coordinates, crs=ccrs.PlateCarree()) 
    
    if title is not None:
        plt.title(title)

# %% [markdown]
# Plot pv energy potential

# %%
warnings.simplefilter(action='ignore', category=FutureWarning)
plot_voronoi(
    pypsa.Network(network_path),
    "solar",
    "onshore",
    "OrRd",
    ccrs.PlateCarree(),
    title="Solar Photovoltaic Potential Density [MW/km2]",
)
warnings.simplefilter(action='default', category=FutureWarning)
# Out:
# INFO:pypsa.io:Imported network elec.nc has buses, carriers, generators, lines, loads, storage_units, transformers

# %% [markdown]
# Plot wind energy potential

# %%
warnings.simplefilter(action='ignore', category=FutureWarning)
plot_voronoi(
    pypsa.Network(network_path),
    "onwind",
    "onshore",
    "Blues",
    ccrs.PlateCarree(),
    title="Onshore Wind Potential Density [MW/km2]",
)
warnings.simplefilter(action='default', category=FutureWarning)
# Out:
# INFO:pypsa.io:Imported network elec.nc has buses, carriers, generators, lines, loads, storage_units, transformers

# %% [markdown]
# Levelized cost of electricity

# %%
# Calculation levelzied cost of electricity in €/MWh based on overall costs and electricity generation
# n.statistics.market_value() ?
lcoe = n.objective/n.statistics.energy_balance().Generator.sum()
lcoe
# Out:
# 41.382233286645906

# %%
# Calculation levelzied cost of electricity in €/MWh based on overall costs and electricity demand
lcoe = n.objective/n.statistics.energy_balance().Load.sum()*(-1)
lcoe
# Out:
# 41.7256825750005

# %%
n.statistics.market_value()
# Out:
# WARNING:pypsa.statistics:Network has multiple bus carriers which are aggregated together. To separate bus carriers set `bus_carrier` or use groupers like `get_carrier_and_bus_carrier`.
# component    carrier
# Generator    Offshore Wind (AC)     60.980792
#              Onshore Wind          120.500485
#              Run of River           47.886958
#              Solar                  35.381612
#              load                   43.886462
# Line         AC                      1.126230
# Link         H2 electrolysis        57.363948
#              H2 fuel cell          104.777094
#              battery charger         0.753175
#              battery discharger     -0.944670
# Load         -                            NaN
# StorageUnit  Reservoir & Dam       336.010849
# Store        Battery Storage       185.986626
#              Hydrogen Storage       50.465329
# dtype: float64

# %% [markdown]
# Check storages

# %%
n.storage_units
# Out:
#                 carrier        bus  p_nom    max_hours  p_min_pu  \
# StorageUnit
# DZ.8_1_AC hydro   hydro  DZ.8_1_AC  100.0  2710.628395       0.0
#
#                  efficiency_dispatch  efficiency_store  \
# StorageUnit
# DZ.8_1_AC hydro                  0.9               0.0
#
#                  cyclic_state_of_charge control  marginal_cost  ...  \
# StorageUnit                                                     ...
# DZ.8_1_AC hydro                    True                0.00992  ...
#
#                  marginal_cost_quadratic capital_cost  build_year  lifetime  \
# StorageUnit
# DZ.8_1_AC hydro                      0.0          0.0           0       inf
#
#                  state_of_charge_initial  state_of_charge_initial_per_period  \
# StorageUnit
# DZ.8_1_AC hydro                      0.0                               False
#
#                  state_of_charge_set  cyclic_state_of_charge_per_period  \
# StorageUnit
# DZ.8_1_AC hydro                  NaN                               True
#
#                  standing_loss  inflow
# StorageUnit
# DZ.8_1_AC hydro            0.0     0.0
#
# [1 rows x 30 columns]

# %% [markdown]
# ## Additional input (Marco)

# %%
CCGT_col = [col for col in n.generators_t.p.columns if 'CCGT' in col]
n.generators_t.p[CCGT_col].sum()
# Out:
# Generator
# DZ.10_1_AC CCGT    0.0
# DZ.13_1_AC CCGT    0.0
# DZ.16_1_AC CCGT    0.0
# DZ.19_1_AC CCGT    0.0
# DZ.23_1_AC CCGT    0.0
# DZ.24_1_AC CCGT    0.0
# DZ.25_1_AC CCGT    0.0
# DZ.26_1_AC CCGT    0.0
# DZ.28_1_AC CCGT    0.0
# DZ.30_1_AC CCGT    0.0
# DZ.31_1_AC CCGT    0.0
# DZ.32_1_AC CCGT    0.0
# DZ.33_1_AC CCGT    0.0
# DZ.34_1_AC CCGT    0.0
# DZ.35_1_AC CCGT    0.0
# DZ.37_1_AC CCGT    0.0
# DZ.39_1_AC CCGT    0.0
# DZ.3_1_AC CCGT     0.0
# DZ.41_1_AC CCGT    0.0
# DZ.43_1_AC CCGT    0.0
# DZ.45_1_AC CCGT    0.0
# DZ.4_1_AC CCGT     0.0
# DZ.5_1_AC CCGT     0.0
# DZ.6_1_AC CCGT     0.0
# DZ.9_1_AC CCGT     0.0
# dtype: float64

# %%
n.generators_t.p.columns
# Out:
# Index(['DZ.10_1_AC CCGT', 'DZ.10_1_AC H2 load', 'DZ.10_1_AC battery load',
#        'DZ.10_1_AC load', 'DZ.10_1_AC onwind', 'DZ.10_1_AC solar',
#        'DZ.11_1_AC H2 load', 'DZ.11_1_AC battery load', 'DZ.11_1_AC load',
#        'DZ.11_1_AC onwind',
#        ...
#        'DZ.8_1_AC load', 'DZ.8_1_AC onwind', 'DZ.8_1_AC ror',
#        'DZ.8_1_AC solar', 'DZ.9_1_AC CCGT', 'DZ.9_1_AC H2 load',
#        'DZ.9_1_AC battery load', 'DZ.9_1_AC load', 'DZ.9_1_AC onwind',
#        'DZ.9_1_AC solar'],
#       dtype='object', name='Generator', length=268)

# %%
n.generators_t.p
# Out:
# Generator            DZ.10_1_AC CCGT  DZ.10_1_AC H2 load  \
# snapshot
# 2013-01-01 00:00:00              0.0            0.000032
# 2013-01-01 12:00:00              0.0            0.000032
# 2013-01-02 00:00:00              0.0            0.000032
# 2013-01-02 12:00:00              0.0            0.000032
# 2013-01-03 00:00:00              0.0            0.000032
# ...                              ...                 ...
# 2013-12-29 12:00:00              0.0            0.000032
# 2013-12-30 00:00:00              0.0            0.000032
# 2013-12-30 12:00:00              0.0            0.000032
# 2013-12-31 00:00:00              0.0            0.000032
# 2013-12-31 12:00:00              0.0            0.000032
#
# Generator            DZ.10_1_AC battery load  DZ.10_1_AC load  \
# snapshot
# 2013-01-01 00:00:00                 0.000032         0.000032
# 2013-01-01 12:00:00                 0.000032         0.000032
# 2013-01-02 00:00:00                 0.000032         0.000032
# 2013-01-02 12:00:00                 0.000032         0.000032
# 2013-01-03 00:00:00                 0.000032         0.000032
# ...                                      ...              ...
# 2013-12-29 12:00:00                 0.000032         0.000032
# 2013-12-30 00:00:00                 0.000032         0.000032
# 2013-12-30 12:00:00                 0.000032         0.000032
# 2013-12-31 00:00:00                 0.000033         0.000033
# 2013-12-31 12:00:00                 0.000032         0.000032
#
# Generator            DZ.10_1_AC onwind  DZ.10_1_AC solar  DZ.11_1_AC H2 load  \
# snapshot
# 2013-01-01 00:00:00           0.000028          0.014914            0.000032
# 2013-01-01 12:00:00           0.000024          0.017840            0.000032
# 2013-01-02 00:00:00           0.000008          0.010721            0.000032
# 2013-01-02 12:00:00           0.000010          0.018627            0.000032
# 2013-01-03 00:00:00           0.000006          0.008387            0.000032
# ...                                ...               ...                 ...
# 2013-12-29 12:00:00           0.000027          0.005141            0.000032
# 2013-12-30 00:00:00           0.000016          0.011802            0.000032
# 2013-12-30 12:00:00           0.000006          0.006764            0.000032
# 2013-12-31 00:00:00           0.000000          0.017274            0.000032
# 2013-12-31 12:00:00           0.000003          0.021264            0.000032
#
# Generator            DZ.11_1_AC battery load  DZ.11_1_AC load  \
# snapshot
# 2013-01-01 00:00:00                 0.000032         0.000032
# 2013-01-01 12:00:00                 0.000032         0.000032
# 2013-01-02 00:00:00                 0.000032         0.000032
# 2013-01-02 12:00:00                 0.000032         0.000032
# 2013-01-03 00:00:00                 0.000032         0.000032
# ...                                      ...              ...
# 2013-12-29 12:00:00                 0.000032         0.000032
# 2013-12-30 00:00:00                 0.000032         0.000032
# 2013-12-30 12:00:00                 0.000031         0.000032
# 2013-12-31 00:00:00                 0.000033         0.000033
# 2013-12-31 12:00:00                 0.000032         0.000032
#
# Generator            DZ.11_1_AC onwind  ...  DZ.8_1_AC load  DZ.8_1_AC onwind  \
# snapshot                                ...
# 2013-01-01 00:00:00           0.000022  ...        0.000032          0.000036
# 2013-01-01 12:00:00           0.000014  ...        0.000032          0.000024
# 2013-01-02 00:00:00           0.000000  ...        0.000032          0.000045
# 2013-01-02 12:00:00           0.000010  ...        0.000032          0.000016
# 2013-01-03 00:00:00           0.000015  ...        0.000032          0.000000
# ...                                ...  ...             ...               ...
# 2013-12-29 12:00:00           0.000036  ...        0.000032          0.000021
# 2013-12-30 00:00:00           0.000020  ...        0.000032          0.000000
# 2013-12-30 12:00:00           0.000013  ...        0.000032          0.000008
# 2013-12-31 00:00:00           0.000000  ...        0.000033          0.000024
# 2013-12-31 12:00:00           0.000000  ...        0.000032          0.000000
#
# Generator            DZ.8_1_AC ror  DZ.8_1_AC solar  DZ.9_1_AC CCGT  \
# snapshot
# 2013-01-01 00:00:00      21.377912         0.029438             0.0
# 2013-01-01 12:00:00      21.377913         0.046479             0.0
# 2013-01-02 00:00:00      21.377912         0.013519             0.0
# 2013-01-02 12:00:00      21.377912         0.027598             0.0
# 2013-01-03 00:00:00      21.377912         0.020397             0.0
# ...                            ...              ...             ...
# 2013-12-29 12:00:00      21.377909         0.005501             0.0
# 2013-12-30 00:00:00      21.377908         0.014742             0.0
# 2013-12-30 12:00:00      21.260472         0.013878             0.0
# 2013-12-31 00:00:00      21.377914         0.027422             0.0
# 2013-12-31 12:00:00      21.377910         0.046798             0.0
#
# Generator            DZ.9_1_AC H2 load  DZ.9_1_AC battery load  \
# snapshot
# 2013-01-01 00:00:00           0.000032                0.000032
# 2013-01-01 12:00:00           0.000032                0.000032
# 2013-01-02 00:00:00           0.000032                0.000032
# 2013-01-02 12:00:00           0.000032                0.000032
# 2013-01-03 00:00:00           0.000032                0.000032
# ...                                ...                     ...
# 2013-12-29 12:00:00           0.000032                0.000032
# 2013-12-30 00:00:00           0.000032                0.000032
# 2013-12-30 12:00:00           0.000032                0.000032
# 2013-12-31 00:00:00           0.000032                0.000033
# 2013-12-31 12:00:00           0.000032                0.000032
#
# Generator            DZ.9_1_AC load  DZ.9_1_AC onwind  DZ.9_1_AC solar
# snapshot
# 2013-01-01 00:00:00        0.000032          0.000049         0.488568
# 2013-01-01 12:00:00        0.000032          0.000054         0.801319
# 2013-01-02 00:00:00        0.000032          0.000010         0.317637
# 2013-01-02 12:00:00        0.000032          0.000000         0.595484
# 2013-01-03 00:00:00        0.000032          0.000221         0.248568
# ...                             ...               ...              ...
# 2013-12-29 12:00:00        0.000032          0.000373         0.295076
# 2013-12-30 00:00:00        0.000032          0.000734         0.054082
# 2013-12-30 12:00:00        0.000032          0.000170         0.065000
# 2013-12-31 00:00:00        0.000033          0.000194         0.500081
# 2013-12-31 12:00:00        0.000032          0.000018         0.828557
#
# [730 rows x 268 columns]

# %%
import re

df = n.generators_t.p

# Extract the category (everything after "GH0 <number> ")
categories = [re.sub(r'GH0 \d+ ', '', col) for col in df.columns]

# Create a mapping from the original column names to their categories
column_mapping = dict(zip(df.columns, categories))

# Group by category
grouped = {}
for col, category in column_mapping.items():
    grouped.setdefault(category, []).append(col)

# Print grouped columns
for category, cols in grouped.items():
    print(f"{category}: {cols}")

print(grouped)
# Out:
# DZ.10_1_AC CCGT: ['DZ.10_1_AC CCGT']
# DZ.10_1_AC H2 load: ['DZ.10_1_AC H2 load']
# DZ.10_1_AC battery load: ['DZ.10_1_AC battery load']
# DZ.10_1_AC load: ['DZ.10_1_AC load']
# DZ.10_1_AC onwind: ['DZ.10_1_AC onwind']
# DZ.10_1_AC solar: ['DZ.10_1_AC solar']
# DZ.11_1_AC H2 load: ['DZ.11_1_AC H2 load']
# DZ.11_1_AC battery load: ['DZ.11_1_AC battery load']
# DZ.11_1_AC load: ['DZ.11_1_AC load']
# DZ.11_1_AC onwind: ['DZ.11_1_AC onwind']
# DZ.11_1_AC solar: ['DZ.11_1_AC solar']
# DZ.12_1_AC H2 load: ['DZ.12_1_AC H2 load']
# DZ.12_1_AC battery load: ['DZ.12_1_AC battery load']
# DZ.12_1_AC load: ['DZ.12_1_AC load']
# DZ.12_1_AC onwind: ['DZ.12_1_AC onwind']
# DZ.12_1_AC solar: ['DZ.12_1_AC solar']
# DZ.13_1_AC CCGT: ['DZ.13_1_AC CCGT']
# DZ.13_1_AC H2 load: ['DZ.13_1_AC H2 load']
# DZ.13_1_AC battery load: ['DZ.13_1_AC battery load']
# DZ.13_1_AC load: ['DZ.13_1_AC load']
# DZ.13_1_AC onwind: ['DZ.13_1_AC onwind']
# DZ.13_1_AC solar: ['DZ.13_1_AC solar']
# DZ.14_1_AC H2 load: ['DZ.14_1_AC H2 load']
# DZ.14_1_AC battery load: ['DZ.14_1_AC battery load']
# DZ.14_1_AC load: ['DZ.14_1_AC load']
# DZ.14_1_AC onwind: ['DZ.14_1_AC onwind']
# DZ.14_1_AC solar: ['DZ.14_1_AC solar']
# DZ.15_1_AC H2 load: ['DZ.15_1_AC H2 load']
# DZ.15_1_AC battery load: ['DZ.15_1_AC battery load']
# DZ.15_1_AC load: ['DZ.15_1_AC load']
# DZ.15_1_AC onwind: ['DZ.15_1_AC onwind']
# DZ.15_1_AC solar: ['DZ.15_1_AC solar']
# DZ.16_1_AC CCGT: ['DZ.16_1_AC CCGT']
# DZ.16_1_AC H2 load: ['DZ.16_1_AC H2 load']
# DZ.16_1_AC battery load: ['DZ.16_1_AC battery load']
# DZ.16_1_AC load: ['DZ.16_1_AC load']
# DZ.16_1_AC onwind: ['DZ.16_1_AC onwind']
# DZ.16_1_AC solar: ['DZ.16_1_AC solar']
# DZ.17_1_AC H2 load: ['DZ.17_1_AC H2 load']
# DZ.17_1_AC battery load: ['DZ.17_1_AC battery load']
# DZ.17_1_AC load: ['DZ.17_1_AC load']
# DZ.17_1_AC onwind: ['DZ.17_1_AC onwind']
# DZ.17_1_AC solar: ['DZ.17_1_AC solar']
# DZ.18_1_AC H2 load: ['DZ.18_1_AC H2 load']
# DZ.18_1_AC battery load: ['DZ.18_1_AC battery load']
# DZ.18_1_AC load: ['DZ.18_1_AC load']
# DZ.18_1_AC onwind: ['DZ.18_1_AC onwind']
# DZ.18_1_AC solar: ['DZ.18_1_AC solar']
# DZ.19_1_AC CCGT: ['DZ.19_1_AC CCGT']
# DZ.19_1_AC H2 load: ['DZ.19_1_AC H2 load']
# DZ.19_1_AC battery load: ['DZ.19_1_AC battery load']
# DZ.19_1_AC load: ['DZ.19_1_AC load']
# DZ.19_1_AC onwind: ['DZ.19_1_AC onwind']
# DZ.19_1_AC solar: ['DZ.19_1_AC solar']
# DZ.1_1_AC H2 load: ['DZ.1_1_AC H2 load']
# DZ.1_1_AC battery load: ['DZ.1_1_AC battery load']
# DZ.1_1_AC load: ['DZ.1_1_AC load']
# DZ.1_1_AC oil: ['DZ.1_1_AC oil']
# DZ.1_1_AC onwind: ['DZ.1_1_AC onwind']
# DZ.1_1_AC solar: ['DZ.1_1_AC solar']
# DZ.20_1_AC H2 load: ['DZ.20_1_AC H2 load']
# DZ.20_1_AC battery load: ['DZ.20_1_AC battery load']
# DZ.20_1_AC load: ['DZ.20_1_AC load']
# DZ.20_1_AC onwind: ['DZ.20_1_AC onwind']
# DZ.20_1_AC solar: ['DZ.20_1_AC solar']
# DZ.21_1_AC H2 load: ['DZ.21_1_AC H2 load']
# DZ.21_1_AC battery load: ['DZ.21_1_AC battery load']
# DZ.21_1_AC load: ['DZ.21_1_AC load']
# DZ.21_1_AC onwind: ['DZ.21_1_AC onwind']
# DZ.21_1_AC solar: ['DZ.21_1_AC solar']
# DZ.22_1_AC H2 load: ['DZ.22_1_AC H2 load']
# DZ.22_1_AC battery load: ['DZ.22_1_AC battery load']
# DZ.22_1_AC load: ['DZ.22_1_AC load']
# DZ.22_1_AC onwind: ['DZ.22_1_AC onwind']
# DZ.22_1_AC solar: ['DZ.22_1_AC solar']
# DZ.23_1_AC CCGT: ['DZ.23_1_AC CCGT']
# DZ.23_1_AC H2 load: ['DZ.23_1_AC H2 load']
# DZ.23_1_AC battery load: ['DZ.23_1_AC battery load']
# DZ.23_1_AC load: ['DZ.23_1_AC load']
# DZ.23_1_AC onwind: ['DZ.23_1_AC onwind']
# DZ.23_1_AC solar: ['DZ.23_1_AC solar']
# DZ.24_1_AC CCGT: ['DZ.24_1_AC CCGT']
# DZ.24_1_AC H2 load: ['DZ.24_1_AC H2 load']
# DZ.24_1_AC battery load: ['DZ.24_1_AC battery load']
# DZ.24_1_AC load: ['DZ.24_1_AC load']
# DZ.24_1_AC onwind: ['DZ.24_1_AC onwind']
# DZ.24_1_AC solar: ['DZ.24_1_AC solar']
# DZ.25_1_AC CCGT: ['DZ.25_1_AC CCGT']
# DZ.25_1_AC H2 load: ['DZ.25_1_AC H2 load']
# DZ.25_1_AC battery load: ['DZ.25_1_AC battery load']
# DZ.25_1_AC load: ['DZ.25_1_AC load']
# DZ.25_1_AC onwind: ['DZ.25_1_AC onwind']
# DZ.25_1_AC solar: ['DZ.25_1_AC solar']
# DZ.26_1_AC CCGT: ['DZ.26_1_AC CCGT']
# DZ.26_1_AC H2 load: ['DZ.26_1_AC H2 load']
# DZ.26_1_AC battery load: ['DZ.26_1_AC battery load']
# DZ.26_1_AC load: ['DZ.26_1_AC load']
# DZ.26_1_AC oil: ['DZ.26_1_AC oil']
# DZ.26_1_AC onwind: ['DZ.26_1_AC onwind']
# DZ.26_1_AC solar: ['DZ.26_1_AC solar']
# DZ.27_1_AC H2 load: ['DZ.27_1_AC H2 load']
# DZ.27_1_AC battery load: ['DZ.27_1_AC battery load']
# DZ.27_1_AC load: ['DZ.27_1_AC load']
# DZ.27_1_AC onwind: ['DZ.27_1_AC onwind']
# DZ.27_1_AC solar: ['DZ.27_1_AC solar']
# DZ.28_1_AC CCGT: ['DZ.28_1_AC CCGT']
# DZ.28_1_AC H2 load: ['DZ.28_1_AC H2 load']
# DZ.28_1_AC battery load: ['DZ.28_1_AC battery load']
# DZ.28_1_AC load: ['DZ.28_1_AC load']
# DZ.28_1_AC onwind: ['DZ.28_1_AC onwind']
# DZ.28_1_AC solar: ['DZ.28_1_AC solar']
# DZ.29_1_AC H2 load: ['DZ.29_1_AC H2 load']
# DZ.29_1_AC battery load: ['DZ.29_1_AC battery load']
# DZ.29_1_AC load: ['DZ.29_1_AC load']
# DZ.29_1_AC onwind: ['DZ.29_1_AC onwind']
# DZ.29_1_AC solar: ['DZ.29_1_AC solar']
# DZ.2_1_AC H2 load: ['DZ.2_1_AC H2 load']
# DZ.2_1_AC battery load: ['DZ.2_1_AC battery load']
# DZ.2_1_AC load: ['DZ.2_1_AC load']
# DZ.2_1_AC onwind: ['DZ.2_1_AC onwind']
# DZ.2_1_AC solar: ['DZ.2_1_AC solar']
# DZ.30_1_AC CCGT: ['DZ.30_1_AC CCGT']
# DZ.30_1_AC H2 load: ['DZ.30_1_AC H2 load']
# DZ.30_1_AC battery load: ['DZ.30_1_AC battery load']
# DZ.30_1_AC load: ['DZ.30_1_AC load']
# DZ.30_1_AC onwind: ['DZ.30_1_AC onwind']
# DZ.30_1_AC solar: ['DZ.30_1_AC solar']
# DZ.31_1_AC CCGT: ['DZ.31_1_AC CCGT']
# DZ.31_1_AC H2 load: ['DZ.31_1_AC H2 load']
# DZ.31_1_AC battery load: ['DZ.31_1_AC battery load']
# DZ.31_1_AC load: ['DZ.31_1_AC load']
# DZ.31_1_AC onwind: ['DZ.31_1_AC onwind']
# DZ.31_1_AC solar: ['DZ.31_1_AC solar']
# DZ.32_1_AC CCGT: ['DZ.32_1_AC CCGT']
# DZ.32_1_AC H2 load: ['DZ.32_1_AC H2 load']
# DZ.32_1_AC battery load: ['DZ.32_1_AC battery load']
# DZ.32_1_AC load: ['DZ.32_1_AC load']
# DZ.32_1_AC onwind: ['DZ.32_1_AC onwind']
# DZ.32_1_AC solar: ['DZ.32_1_AC solar']
# DZ.33_1_AC CCGT: ['DZ.33_1_AC CCGT']
# DZ.33_1_AC H2 load: ['DZ.33_1_AC H2 load']
# DZ.33_1_AC battery load: ['DZ.33_1_AC battery load']
# DZ.33_1_AC load: ['DZ.33_1_AC load']
# DZ.33_1_AC onwind: ['DZ.33_1_AC onwind']
# DZ.33_1_AC solar: ['DZ.33_1_AC solar']
# DZ.34_1_AC CCGT: ['DZ.34_1_AC CCGT']
# DZ.34_1_AC H2 load: ['DZ.34_1_AC H2 load']
# DZ.34_1_AC battery load: ['DZ.34_1_AC battery load']
# DZ.34_1_AC load: ['DZ.34_1_AC load']
# DZ.34_1_AC oil: ['DZ.34_1_AC oil']
# DZ.34_1_AC onwind: ['DZ.34_1_AC onwind']
# DZ.34_1_AC solar: ['DZ.34_1_AC solar']
# DZ.35_1_AC CCGT: ['DZ.35_1_AC CCGT']
# DZ.35_1_AC H2 load: ['DZ.35_1_AC H2 load']
# DZ.35_1_AC battery load: ['DZ.35_1_AC battery load']
# DZ.35_1_AC load: ['DZ.35_1_AC load']
# DZ.35_1_AC onwind: ['DZ.35_1_AC onwind']
# DZ.35_1_AC solar: ['DZ.35_1_AC solar']
# DZ.36_1_AC H2 load: ['DZ.36_1_AC H2 load']
# DZ.36_1_AC battery load: ['DZ.36_1_AC battery load']
# DZ.36_1_AC load: ['DZ.36_1_AC load']
# DZ.36_1_AC onwind: ['DZ.36_1_AC onwind']
# DZ.36_1_AC solar: ['DZ.36_1_AC solar']
# DZ.37_1_AC CCGT: ['DZ.37_1_AC CCGT']
# DZ.37_1_AC H2 load: ['DZ.37_1_AC H2 load']
# DZ.37_1_AC battery load: ['DZ.37_1_AC battery load']
# DZ.37_1_AC load: ['DZ.37_1_AC load']
# DZ.37_1_AC onwind: ['DZ.37_1_AC onwind']
# DZ.37_1_AC solar: ['DZ.37_1_AC solar']
# DZ.38_1_AC H2 load: ['DZ.38_1_AC H2 load']
# DZ.38_1_AC battery load: ['DZ.38_1_AC battery load']
# DZ.38_1_AC load: ['DZ.38_1_AC load']
# DZ.38_1_AC onwind: ['DZ.38_1_AC onwind']
# DZ.38_1_AC solar: ['DZ.38_1_AC solar']
# DZ.39_1_AC CCGT: ['DZ.39_1_AC CCGT']
# DZ.39_1_AC H2 load: ['DZ.39_1_AC H2 load']
# DZ.39_1_AC battery load: ['DZ.39_1_AC battery load']
# DZ.39_1_AC load: ['DZ.39_1_AC load']
# DZ.39_1_AC oil: ['DZ.39_1_AC oil']
# DZ.39_1_AC onwind: ['DZ.39_1_AC onwind']
# DZ.39_1_AC solar: ['DZ.39_1_AC solar']
# DZ.3_1_AC CCGT: ['DZ.3_1_AC CCGT']
# DZ.3_1_AC H2 load: ['DZ.3_1_AC H2 load']
# DZ.3_1_AC battery load: ['DZ.3_1_AC battery load']
# DZ.3_1_AC load: ['DZ.3_1_AC load']
# DZ.3_1_AC onwind: ['DZ.3_1_AC onwind']
# DZ.3_1_AC solar: ['DZ.3_1_AC solar']
# DZ.40_1_AC H2 load: ['DZ.40_1_AC H2 load']
# DZ.40_1_AC battery load: ['DZ.40_1_AC battery load']
# DZ.40_1_AC load: ['DZ.40_1_AC load']
# DZ.40_1_AC onwind: ['DZ.40_1_AC onwind']
# DZ.40_1_AC solar: ['DZ.40_1_AC solar']
# DZ.41_1_AC CCGT: ['DZ.41_1_AC CCGT']
# DZ.41_1_AC H2 load: ['DZ.41_1_AC H2 load']
# DZ.41_1_AC battery load: ['DZ.41_1_AC battery load']
# DZ.41_1_AC load: ['DZ.41_1_AC load']
# DZ.41_1_AC onwind: ['DZ.41_1_AC onwind']
# DZ.41_1_AC solar: ['DZ.41_1_AC solar']
# DZ.42_1_AC H2 load: ['DZ.42_1_AC H2 load']
# DZ.42_1_AC battery load: ['DZ.42_1_AC battery load']
# DZ.42_1_AC load: ['DZ.42_1_AC load']
# DZ.42_1_AC onwind: ['DZ.42_1_AC onwind']
# DZ.42_1_AC solar: ['DZ.42_1_AC solar']
# DZ.43_1_AC CCGT: ['DZ.43_1_AC CCGT']
# DZ.43_1_AC H2 load: ['DZ.43_1_AC H2 load']
# DZ.43_1_AC battery load: ['DZ.43_1_AC battery load']
# DZ.43_1_AC load: ['DZ.43_1_AC load']
# DZ.43_1_AC onwind: ['DZ.43_1_AC onwind']
# DZ.43_1_AC solar: ['DZ.43_1_AC solar']
# DZ.45_1_AC CCGT: ['DZ.45_1_AC CCGT']
# DZ.45_1_AC H2 load: ['DZ.45_1_AC H2 load']
# DZ.45_1_AC battery load: ['DZ.45_1_AC battery load']
# DZ.45_1_AC load: ['DZ.45_1_AC load']
# DZ.45_1_AC onwind: ['DZ.45_1_AC onwind']
# DZ.45_1_AC solar: ['DZ.45_1_AC solar']
# DZ.46_1_AC H2 load: ['DZ.46_1_AC H2 load']
# DZ.46_1_AC battery load: ['DZ.46_1_AC battery load']
# DZ.46_1_AC load: ['DZ.46_1_AC load']
# DZ.46_1_AC onwind: ['DZ.46_1_AC onwind']
# DZ.46_1_AC solar: ['DZ.46_1_AC solar']
# DZ.47_1_AC H2 load: ['DZ.47_1_AC H2 load']
# DZ.47_1_AC battery load: ['DZ.47_1_AC battery load']
# DZ.47_1_AC load: ['DZ.47_1_AC load']
# DZ.47_1_AC onwind: ['DZ.47_1_AC onwind']
# DZ.47_1_AC solar: ['DZ.47_1_AC solar']
# DZ.48_1_AC H2 load: ['DZ.48_1_AC H2 load']
# DZ.48_1_AC battery load: ['DZ.48_1_AC battery load']
# DZ.48_1_AC load: ['DZ.48_1_AC load']
# DZ.48_1_AC offwind-ac: ['DZ.48_1_AC offwind-ac']
# DZ.48_1_AC offwind-dc: ['DZ.48_1_AC offwind-dc']
# DZ.48_1_AC onwind: ['DZ.48_1_AC onwind']
# DZ.48_1_AC solar: ['DZ.48_1_AC solar']
# DZ.4_1_AC CCGT: ['DZ.4_1_AC CCGT']
# DZ.4_1_AC H2 load: ['DZ.4_1_AC H2 load']
# DZ.4_1_AC battery load: ['DZ.4_1_AC battery load']
# DZ.4_1_AC load: ['DZ.4_1_AC load']
# DZ.4_1_AC oil: ['DZ.4_1_AC oil']
# DZ.4_1_AC onwind: ['DZ.4_1_AC onwind']
# DZ.4_1_AC solar: ['DZ.4_1_AC solar']
# DZ.5_1_AC CCGT: ['DZ.5_1_AC CCGT']
# DZ.5_1_AC H2 load: ['DZ.5_1_AC H2 load']
# DZ.5_1_AC battery load: ['DZ.5_1_AC battery load']
# DZ.5_1_AC load: ['DZ.5_1_AC load']
# DZ.5_1_AC onwind: ['DZ.5_1_AC onwind']
# DZ.5_1_AC solar: ['DZ.5_1_AC solar']
# DZ.6_1_AC CCGT: ['DZ.6_1_AC CCGT']
# DZ.6_1_AC H2 load: ['DZ.6_1_AC H2 load']
# DZ.6_1_AC battery load: ['DZ.6_1_AC battery load']
# DZ.6_1_AC load: ['DZ.6_1_AC load']
# DZ.6_1_AC onwind: ['DZ.6_1_AC onwind']
# DZ.6_1_AC solar: ['DZ.6_1_AC solar']
# DZ.7_1_AC H2 load: ['DZ.7_1_AC H2 load']
# DZ.7_1_AC battery load: ['DZ.7_1_AC battery load']
# DZ.7_1_AC load: ['DZ.7_1_AC load']
# DZ.7_1_AC onwind: ['DZ.7_1_AC onwind']
# DZ.7_1_AC solar: ['DZ.7_1_AC solar']
# DZ.8_1_AC H2 load: ['DZ.8_1_AC H2 load']
# DZ.8_1_AC battery load: ['DZ.8_1_AC battery load']
# DZ.8_1_AC load: ['DZ.8_1_AC load']
# DZ.8_1_AC onwind: ['DZ.8_1_AC onwind']
# DZ.8_1_AC ror: ['DZ.8_1_AC ror']
# DZ.8_1_AC solar: ['DZ.8_1_AC solar']
# DZ.9_1_AC CCGT: ['DZ.9_1_AC CCGT']
# DZ.9_1_AC H2 load: ['DZ.9_1_AC H2 load']
# DZ.9_1_AC battery load: ['DZ.9_1_AC battery load']
# DZ.9_1_AC load: ['DZ.9_1_AC load']
# DZ.9_1_AC onwind: ['DZ.9_1_AC onwind']
# DZ.9_1_AC solar: ['DZ.9_1_AC solar']
# {'DZ.10_1_AC CCGT': ['DZ.10_1_AC CCGT'], 'DZ.10_1_AC H2 load': ['DZ.10_1_AC H2 load'], 'DZ.10_1_AC battery load': ['DZ.10_1_AC battery load'], 'DZ.10_1_AC load': ['DZ.10_1_AC load'], 'DZ.10_1_AC onwind': ['DZ.10_1_AC onwind'], 'DZ.10_1_AC solar': ['DZ.10_1_AC solar'], 'DZ.11_1_AC H2 load': ['DZ.11_1_AC H2 load'], 'DZ.11_1_AC battery load': ['DZ.11_1_AC battery load'], 'DZ.11_1_AC load': ['DZ.11_1_AC load'], 'DZ.11_1_AC onwind': ['DZ.11_1_AC onwind'], 'DZ.11_1_AC solar': ['DZ.11_1_AC solar'], 'DZ.12_1_AC H2 load': ['DZ.12_1_AC H2 load'], 'DZ.12_1_AC battery load': ['DZ.12_1_AC battery load'], 'DZ.12_1_AC load': ['DZ.12_1_AC load'], 'DZ.12_1_AC onwind': ['DZ.12_1_AC onwind'], 'DZ.12_1_AC solar': ['DZ.12_1_AC solar'], 'DZ.13_1_AC CCGT': ['DZ.13_1_AC CCGT'], 'DZ.13_1_AC H2 load': ['DZ.13_1_AC H2 load'], 'DZ.13_1_AC battery load': ['DZ.13_1_AC battery load'], 'DZ.13_1_AC load': ['DZ.13_1_AC load'], 'DZ.13_1_AC onwind': ['DZ.13_1_AC onwind'], 'DZ.13_1_AC solar': ['DZ.13_1_AC solar'], 'DZ.14_1_AC H2 load': ['DZ.14_1_AC H2 load'], 'DZ.14_1_AC battery load': ['DZ.14_1_AC battery load'], 'DZ.14_1_AC load': ['DZ.14_1_AC load'], 'DZ.14_1_AC onwind': ['DZ.14_1_AC onwind'], 'DZ.14_1_AC solar': ['DZ.14_1_AC solar'], 'DZ.15_1_AC H2 load': ['DZ.15_1_AC H2 load'], 'DZ.15_1_AC battery load': ['DZ.15_1_AC battery load'], 'DZ.15_1_AC load': ['DZ.15_1_AC load'], 'DZ.15_1_AC onwind': ['DZ.15_1_AC onwind'], 'DZ.15_1_AC solar': ['DZ.15_1_AC solar'], 'DZ.16_1_AC CCGT': ['DZ.16_1_AC CCGT'], 'DZ.16_1_AC H2 load': ['DZ.16_1_AC H2 load'], 'DZ.16_1_AC battery load': ['DZ.16_1_AC battery load'], 'DZ.16_1_AC load': ['DZ.16_1_AC load'], 'DZ.16_1_AC onwind': ['DZ.16_1_AC onwind'], 'DZ.16_1_AC solar': ['DZ.16_1_AC solar'], 'DZ.17_1_AC H2 load': ['DZ.17_1_AC H2 load'], 'DZ.17_1_AC battery load': ['DZ.17_1_AC battery load'], 'DZ.17_1_AC load': ['DZ.17_1_AC load'], 'DZ.17_1_AC onwind': ['DZ.17_1_AC onwind'], 'DZ.17_1_AC solar': ['DZ.17_1_AC solar'], 'DZ.18_1_AC H2 load': ['DZ.18_1_AC H2 load'], 'DZ.18_1_AC battery load': ['DZ.18_1_AC battery load'], 'DZ.18_1_AC load': ['DZ.18_1_AC load'], 'DZ.18_1_AC onwind': ['DZ.18_1_AC onwind'], 'DZ.18_1_AC solar': ['DZ.18_1_AC solar'], 'DZ.19_1_AC CCGT': ['DZ.19_1_AC CCGT'], 'DZ.19_1_AC H2 load': ['DZ.19_1_AC H2 load'], 'DZ.19_1_AC battery load': ['DZ.19_1_AC battery load'], 'DZ.19_1_AC load': ['DZ.19_1_AC load'], 'DZ.19_1_AC onwind': ['DZ.19_1_AC onwind'], 'DZ.19_1_AC solar': ['DZ.19_1_AC solar'], 'DZ.1_1_AC H2 load': ['DZ.1_1_AC H2 load'], 'DZ.1_1_AC battery load': ['DZ.1_1_AC battery load'], 'DZ.1_1_AC load': ['DZ.1_1_AC load'], 'DZ.1_1_AC oil': ['DZ.1_1_AC oil'], 'DZ.1_1_AC onwind': ['DZ.1_1_AC onwind'], 'DZ.1_1_AC solar': ['DZ.1_1_AC solar'], 'DZ.20_1_AC H2 load': ['DZ.20_1_AC H2 load'], 'DZ.20_1_AC battery load': ['DZ.20_1_AC battery load'], 'DZ.20_1_AC load': ['DZ.20_1_AC load'], 'DZ.20_1_AC onwind': ['DZ.20_1_AC onwind'], 'DZ.20_1_AC solar': ['DZ.20_1_AC solar'], 'DZ.21_1_AC H2 load': ['DZ.21_1_AC H2 load'], 'DZ.21_1_AC battery load': ['DZ.21_1_AC battery load'], 'DZ.21_1_AC load': ['DZ.21_1_AC load'], 'DZ.21_1_AC onwind': ['DZ.21_1_AC onwind'], 'DZ.21_1_AC solar': ['DZ.21_1_AC solar'], 'DZ.22_1_AC H2 load': ['DZ.22_1_AC H2 load'], 'DZ.22_1_AC battery load': ['DZ.22_1_AC battery load'], 'DZ.22_1_AC load': ['DZ.22_1_AC load'], 'DZ.22_1_AC onwind': ['DZ.22_1_AC onwind'], 'DZ.22_1_AC solar': ['DZ.22_1_AC solar'], 'DZ.23_1_AC CCGT': ['DZ.23_1_AC CCGT'], 'DZ.23_1_AC H2 load': ['DZ.23_1_AC H2 load'], 'DZ.23_1_AC battery load': ['DZ.23_1_AC battery load'], 'DZ.23_1_AC load': ['DZ.23_1_AC load'], 'DZ.23_1_AC onwind': ['DZ.23_1_AC onwind'], 'DZ.23_1_AC solar': ['DZ.23_1_AC solar'], 'DZ.24_1_AC CCGT': ['DZ.24_1_AC CCGT'], 'DZ.24_1_AC H2 load': ['DZ.24_1_AC H2 load'], 'DZ.24_1_AC battery load': ['DZ.24_1_AC battery load'], 'DZ.24_1_AC load': ['DZ.24_1_AC load'], 'DZ.24_1_AC onwind': ['DZ.24_1_AC onwind'], 'DZ.24_1_AC solar': ['DZ.24_1_AC solar'], 'DZ.25_1_AC CCGT': ['DZ.25_1_AC CCGT'], 'DZ.25_1_AC H2 load': ['DZ.25_1_AC H2 load'], ...

# %%
import pandas as pd
import re
import matplotlib.pyplot as plt


# Step 1: Extract category names
categories = [re.sub(r'GH0 \d+ ', '', col) for col in df.columns]

# Step 2: Create a mapping from category name to a list of columns
category_columns = {}
for col, category in zip(df.columns, categories):
    if category not in category_columns:
        category_columns[category] = []
    category_columns[category].append(col)

# Step 3: Sum data for each category and create a new DataFrame
grouped_data = pd.DataFrame({category: df[cols].sum(axis=1) for category, cols in category_columns.items()})

# Step 4: Plot the grouped time series
plt.figure(figsize=(12, 6))
for category in grouped_data.columns:
    plt.plot(grouped_data.index, grouped_data[category], label=category, linestyle="-")

# Formatting the plot
plt.xlabel("Time")
plt.ylabel("Power (MW)")  # Adjust based on your data units
plt.title("Power Generation & Load by Category")
plt.legend()
plt.grid(True)
plt.show()

# %%
loads = n.loads_t.p.multiply(n.snapshot_weightings.generators, axis=0)
fig, ax = plt.subplots(figsize=(15, 3))
loads.sum(axis=1).loc['2013-01-01':'2013-01-31'].plot(ax=ax)
ax.set_ylabel('Power in MW')
print('Total load in 2013: {} TWh'.format(n.loads_t.p.multiply(n.snapshot_weightings.generators, axis=0).sum(axis=1).sum() / 1000000))
# Out:
# Total load in 2013: 104.01562756805447 TWh

# %%
n.objective / 1e9 # billion europs p.a.
print("The total system cost is {:.0f} million euros per year".format(n.objective / 1e6))
# Out:
# The total system cost is 4340 million euros per year

# %% [markdown]
# ## Line expansion

# %%
(n.lines.s_nom_opt - n.lines.s_nom).plot.bar()
# Out:
# <AxesSubplot:xlabel='Line'>

# %%
fig, ax = plt.subplots(figsize=(6,6))
n.generators.groupby('carrier').p_nom_opt.sum().multiply(1e-3).plot.bar(ax = ax)
ax.set_title('Optimal generation capacity per carrier')
ax.set_ylabel('Capacity in GW')
# Out:
# Text(0, 0.5, 'Capacity in GW')

# %%
# n.generators.drop(n.generators[n.generators['carrier'] == 'load'], inplace=True)
n.generators = n.generators[n.generators['carrier'] != 'load']

# %%
n.storage_units.groupby('carrier').p_nom_opt.sum() / 1e3 # GW
# Out:
# carrier
# hydro    0.1
# Name: p_nom_opt, dtype: float64

# %%
(n.storage_units_t.state_of_charge.sum(axis=1).resample('D').mean() / 1e6).plot()
# Out:
# <AxesSubplot:xlabel='snapshot'>

# %%
n.storage_units_t.state_of_charge / 1e6
# Out:
# StorageUnit          DZ.8_1_AC hydro
# snapshot
# 2013-01-01 00:00:00         0.098892
# 2013-01-01 12:00:00         0.097579
# 2013-01-02 00:00:00         0.096294
# 2013-01-02 12:00:00         0.095729
# 2013-01-03 00:00:00         0.094613
# ...                              ...
# 2013-12-29 12:00:00         0.102924
# 2013-12-30 00:00:00         0.102510
# 2013-12-30 12:00:00         0.102766
# 2013-12-31 00:00:00         0.101488
# 2013-12-31 12:00:00         0.100203
#
# [730 rows x 1 columns]

# %%
n.storage_units
# Out:
#                 carrier        bus  p_nom    max_hours  p_min_pu  \
# StorageUnit
# DZ.8_1_AC hydro   hydro  DZ.8_1_AC  100.0  2710.628395       0.0
#
#                  efficiency_dispatch  efficiency_store  \
# StorageUnit
# DZ.8_1_AC hydro                  0.9               0.0
#
#                  cyclic_state_of_charge control  marginal_cost  ...  \
# StorageUnit                                                     ...
# DZ.8_1_AC hydro                    True                0.00992  ...
#
#                  marginal_cost_quadratic capital_cost  build_year  lifetime  \
# StorageUnit
# DZ.8_1_AC hydro                      0.0          0.0           0       inf
#
#                  state_of_charge_initial  state_of_charge_initial_per_period  \
# StorageUnit
# DZ.8_1_AC hydro                      0.0                               False
#
#                  state_of_charge_set  cyclic_state_of_charge_per_period  \
# StorageUnit
# DZ.8_1_AC hydro                  NaN                               True
#
#                  standing_loss  inflow
# StorageUnit
# DZ.8_1_AC hydro            0.0     0.0
#
# [1 rows x 30 columns]

# %%
n.generators.groupby(["bus", "carrier"]).p_nom_opt.sum()
# Out:
# bus         carrier
# DZ.10_1_AC  CCGT       1310.000000
#             onwind        0.000426
#             solar         0.161046
# DZ.11_1_AC  onwind        0.000481
#             solar         0.632076
#                           ...
# DZ.8_1_AC   ror          21.377915
#             solar         0.275766
# DZ.9_1_AC   CCGT       2750.000000
#             onwind        0.000956
#             solar         4.234718
# Name: p_nom_opt, Length: 127, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(12,5))
(n.storage_units_t.state_of_charge / 1e6).plot(ax = ax)
ax.set_title('State of charge in TWh')
# Out:
# Text(0.5, 1.0, 'State of charge in TWh')

# %%
(n.storage_units_t.state_of_charge / 1e6)
# Out:
# StorageUnit          DZ.8_1_AC hydro
# snapshot
# 2013-01-01 00:00:00         0.098892
# 2013-01-01 12:00:00         0.097579
# 2013-01-02 00:00:00         0.096294
# 2013-01-02 12:00:00         0.095729
# 2013-01-03 00:00:00         0.094613
# ...                              ...
# 2013-12-29 12:00:00         0.102924
# 2013-12-30 00:00:00         0.102510
# 2013-12-30 12:00:00         0.102766
# 2013-12-31 00:00:00         0.101488
# 2013-12-31 12:00:00         0.100203
#
# [730 rows x 1 columns]

# %%
(n.loads_t.p.sum(axis=1).multiply(n.snapshot_weightings.generators) / 1e3).loc['2013-07'].plot()
# Out:
# <AxesSubplot:xlabel='snapshot'>

# %%
(n.generators_t.p.sum(axis=1).multiply(n.snapshot_weightings.generators) / 1e3).loc['2013-07'].plot()
# Out:
# <AxesSubplot:xlabel='snapshot'>

# %%
gen_snap = n.generators_t.p.loc['2013-01-01 18:00:00']
gen_snap
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File index.pyx:609, in pandas._libs.index.DatetimeEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1357063200000000000
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/pypsa-earth-2/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:577, in pandas._libs.index.DatetimeEngine.get_loc()
#
# File index.pyx:611, in pandas._libs.index.DatetimeEngine.get_loc()
#
# KeyError: Timestamp('2013-01-01 18:00:00')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/pypsa-earth-2/lib/python3.10/site-packages/pandas/core/indexes/datetimes.py:630, in DatetimeIndex.get_loc(self, key)
#     629 try:
# --> 630     return Index.get_loc(self, key)
#     631 except KeyError as err:
#
# File ~/miniconda3/envs/pypsa-earth-2/lib/python3.10/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#
# KeyError: Timestamp('2013-01-01 18:00:00')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 gen_snap = n.generators_t.p.loc['2013-01-01 18:00:00']
#       2 gen_snap
#
# File ~/miniconda3/envs/pypsa-earth-2/lib/python3.10/site-packages/pandas/core/indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/miniconda3/envs/pypsa-earth-2/lib/python3.10/site-packages/pandas/core/indexing.py:1431, in _LocIndexer._getitem_axis(self, key, axis)
#    1429 # fall thru to straight lookup
#    1430 self._validate_key(key, axis)
# -> 1431 return self._get_label(key, axis=axis)
#
# File ~/miniconda3/envs/pypsa-earth-2/lib/python3.10/site-packages/pandas/core/indexing.py:1381, in _LocIndexer._get_label(self, label, axis)
#    1379 def _get_label(self, label, axis: AxisInt):
#    1380     # GH#5567 this will fail if the label is not present in the axis.
# -> 1381     return self.obj.xs(label, axis=axis)
#
# File ~/miniconda3/envs/pypsa-earth-2/lib/python3.10/site-packages/pandas/core/generic.py:4301, in NDFrame.xs(self, key, axis, level, drop_level)
#    4299             new_index = index[loc]
#    4300 else:
# -> 4301     loc = index.get_loc(key)
#    4303     if isinstance(loc, np.ndarray):
#    4304         if loc.dtype == np.bool_:
#
# File ~/miniconda3/envs/pypsa-earth-2/lib/python3.10/site-packages/pandas/core/indexes/datetimes.py:632, in DatetimeIndex.get_loc(self, key)
#     630     return Index.get_loc(self, key)
#     631 except KeyError as err:
# --> 632     raise KeyError(orig_key) from err
#
# KeyError: '2013-01-01 18:00:00'

# %%
n.storage_units_t.inflow.multiply(n.snapshot_weightings.generators, axis=0).loc['2013-07'].plot()
# Out:
# <AxesSubplot:xlabel='snapshot'>

# %%
n.statistics.capacity_factor(comps=["Generator", "StorageUnit"]).round(2)
# Out:
# component    carrier
# Generator    Offshore Wind (DC)    0.07
#              Onshore Wind          0.11
#              Run of River          1.00
#              Solar                 0.13
# StorageUnit  Reservoir & Dam       0.62
# dtype: float64

# %%
n.statistics.supply().loc["StorageUnit"] / 1e6 # from MWh to TWh
# Out:
# WARNING:pypsa.statistics:Network has multiple bus carriers which are aggregated together. To separate bus carriers set `bus_carrier` or use groupers like `get_carrier_and_bus_carrier`.
# carrier
# Reservoir & Dam    7.686043
# dtype: float64

# %%
n.statistics.dispatch(comps=["Generator", "StorageUnit"]).round(2) / 1e6
# Out:
# /tmp/ipykernel_18353/2211605357.py:1: DeprecatedWarning: dispatch is deprecated as of 0.28 and will be removed in 0.29. Use 'energy_balance' instead.
#   n.statistics.dispatch(comps=["Generator", "StorageUnit"]).round(2) / 1e6
# WARNING:pypsa.statistics:Network has multiple bus carriers which are aggregated together. To separate bus carriers set `bus_carrier` or use groupers like `get_carrier_and_bus_carrier`.
# component    carrier
# Generator    Offshore Wind (DC)    3.000000e-08
#              Onshore Wind          2.913540e-01
#              Run of River          1.401528e+00
#              Solar                 1.131490e+01
# StorageUnit  Reservoir & Dam       7.686043e+00
# dtype: float64

# %%
(n.storage_units_t.inflow.sum(axis=0) / 1e6 * 3).sum()# TWh
# Out:
# 9.862710000000002

# %%
(n.storage_units_t.p.sum(axis=0) / 1e6 * 3).sum() # TWh
# Out:
# 7.686043128490364

# %%
n.storage_units_t.spill.sum(axis=0) / 1e6
# Out:
# StorageUnit
# GH.11_2_AC hydro    0.000021
# GH.6_2_AC hydro     0.440866
# dtype: float64

# %%
n.statistics.supply() / 1e6
# Out:
# WARNING:pypsa.statistics:Network has multiple bus carriers which are aggregated together. To separate bus carriers set `bus_carrier` or use groupers like `get_carrier_and_bus_carrier`.
# component    carrier
# StorageUnit  Reservoir & Dam       7.686043e+00
# Line         AC                    2.769693e+01
# Link         H2 electrolysis       6.938188e-01
#              H2 fuel cell          4.024149e-01
#              battery charger       2.722818e+00
#              battery discharger    2.450536e+00
# Store        Battery Storage       2.722279e+00
#              Hydrogen Storage      6.934614e-01
# Generator    Offshore Wind (DC)    2.986375e-08
#              Onshore Wind          2.913540e-01
#              Run of River          1.401528e+00
#              Solar                 1.131490e+01
# dtype: float64

# %%
hydro_storage = n.storage_units["p_nom"] * n.storage_units["max_hours"] / 1e6 # TWh
print(hydro_storage)
# Out:
# StorageUnit
# GH.11_2_AC hydro    0.851124
# GH.6_2_AC hydro     2.148876
# dtype: float64

# %%
n.storage_units_t.inflow
type(n.storage_units_t.p)

# Assuming n.storage_units_t.inflow and n.storage_units_t.p are Pandas DataFrames
fig, ax = plt.subplots(figsize=(12, 6))

# Plot inflow
ax.plot(n.storage_units_t.inflow.loc["2013-5-01":"2013-5-07", 'GH.6_2_AC hydro'], label='Inflow', linestyle='-', marker='')

# Plot p
ax.plot(n.storage_units_t.p.loc["2013-5-01":"2013-5-07", 'GH.6_2_AC hydro'], label='Power Output', linestyle='--', marker='')

ax.set_xlabel('Time')
ax.set_ylabel('Value')
ax.set_title('Storage Unit Inflow and Power Output Over Time')
ax.legend()
ax.grid(True)

plt.show()

# %%
(n.storage_units_t.state_of_charge.loc["2013-5-01":"2013-5-07", 'GH.6_2_AC hydro'] / 1e6).plot()
# Out:
# <AxesSubplot:xlabel='snapshot'>

# %%
n.storage_units.p_nom * n.storage_units.max_hours
# Out:
# StorageUnit
# GH.11_2_AC hydro    8.511236e+05
# GH.6_2_AC hydro     2.148876e+06
# dtype: float64

# %%
n.statistics()
# Out:
#                                 Optimal Capacity  Installed Capacity  \
# Generator   Combined-Cycle Gas       3952.154566         3952.154566
#             Offshore Wind (DC)          0.000049            0.000000
#             Oil                       509.484522          509.484522
#             Onshore Wind              314.181800            0.000000
#             Run of River              160.000000          160.000000
#             Solar                    9615.070230          168.954000
# Line        AC                      20392.073854        20278.920137
# Link        H2 electrolysis           782.267599            0.000000
#             H2 fuel cell              465.681202            0.000000
#             battery charger          1454.010084            0.000000
#             battery discharger       1615.566760            0.000000
# Load        -                           0.000000            0.000000
# StorageUnit Reservoir & Dam          1424.000000         1424.000000
# Store       Battery Storage          8603.302257            0.000000
#             Hydrogen Storage         7525.170733            0.000000
#
#                                       Supply    Withdrawal      Dispatch  \
# Generator   Combined-Cycle Gas  0.000000e+00  0.000000e+00  0.000000e+00
#             Offshore Wind (DC)  2.986375e-02  0.000000e+00  2.986375e-02
#             Oil                 0.000000e+00  0.000000e+00  0.000000e+00
#             Onshore Wind        2.913540e+05  0.000000e+00  2.913540e+05
#             Run of River        1.401528e+06  0.000000e+00  1.401528e+06
#             Solar               1.131490e+07  0.000000e+00  1.131490e+07
# Line        AC                  2.769693e+07  2.769693e+07  0.000000e+00
# Link        H2 electrolysis     6.938188e+05  8.672736e+05 -1.734547e+05
#             H2 fuel cell        4.024149e+05  6.938188e+05 -2.914039e+05
#             battery charger     2.722818e+06  3.025354e+06 -3.025354e+05
#             battery discharger  2.450536e+06  2.722818e+06 -2.722818e+05
# Load        -                   0.000000e+00  1.965415e+07 -1.965415e+07
# StorageUnit Reservoir & Dam     7.686043e+06  0.000000e+00  7.686043e+06
# Store       Battery Storage     2.722279e+06  2.722279e+06 -1.818350e-10
#             Hydrogen Storage    6.934614e+05  6.934614e+05 -1.624372e-10
#
#                                 Transmission  Capacity Factor   Curtailment  \
# Generator   Combined-Cycle Gas      0.000000         0.000000  0.000000e+00
#             Offshore Wind (DC)      0.000000         0.070139  1.812026e-02
#             Oil                     0.000000         0.000000  0.000000e+00
#             Onshore Wind            0.000000         0.105861  5.173460e+04
#             Run of River            0.000000         0.999948  0.000000e+00
#             Solar                   0.000000         0.134337  1.514736e+06
# Line        AC                 -26507.690442         0.155048  0.000000e+00
# Link        H2 electrolysis         0.000000         0.126560  0.000000e+00
#             H2 fuel cell            0.000000         0.170080  0.000000e+00
#             battery charger         0.000000         0.237522  0.000000e+00
#             battery discharger      0.000000         0.192393  0.000000e+00
# Load        -                       0.000000              NaN  0.000000e+00
# StorageUnit Reservoir & Dam         0.000000         0.616153  0.000000e+00
# Store       Battery Storage         0.000000         0.437892  0.000000e+00
#             Hydrogen Storage        0.000000         0.504564  0.000000e+00
#
#                                 Capital Expenditure  Operational Expenditure  \
# Generator   Combined-Cycle Gas         3.338350e+08             0.000000e+00
#             Offshore Wind (DC)         1.223816e+01             7.200124e-04
#             Oil                        1.947992e+07             0.000000e+00
#             Onshore Wind               3.433868e+07             7.536445e+03
#             Run of River               4.335051e+07             1.500034e+04
#             Solar                      4.889836e+08             2.202044e+05
# Line        AC                         1.318060e+08             0.000000e+00
# Link        H2 electrolysis            3.817029e+07             8.593037e+03
#             H2 fuel cell               1.138969e+07             6.623176e+03
#             battery charger            5.599061e+07             3.024963e+04
#             battery discharger         0.000000e+00             2.490283e+04
# Load        -                          0.000000e+00             0.000000e+00
# StorageUnit Reservoir & Dam            0.000000e+00             8.162444e+04
# Store       Battery Storage            1.366022e+08             9.367507e-13
#             Hydrogen Storage           5.992170e+06            -1.563749e-13
#
#                                      Revenue  Market Value
# Generator   Combined-Cycle Gas  0.000000e+00      0.000000
#             Offshore Wind (DC)  0.000000e+00           NaN
#             Oil                 0.000000e+00      0.000000
#             Onshore Wind        0.000000e+00           NaN
#             Run of River        0.000000e+00           NaN
#             Solar               0.000000e+00           NaN
# Line        AC                  2.151333e+07      0.776741
# Link        H2 electrolysis     3.817880e+07     55.027049
#             H2 fuel cell        1.139626e+07     28.319680
#             battery charger     5.524191e+07     20.288506
#             battery discharger  8.037111e+05      0.327974
# Load        -                  -1.691091e+09           NaN
# StorageUnit Reservoir & Dam     7.797314e+08    101.447695
# Store       Battery Storage     1.366022e+08     50.179351
#             Hydrogen Storage    5.992143e+06      8.640918

# %%
energy_balance_check = n.statistics.energy_balance().loc[:, :, "AC"]
energy_balance_check
# Out:
# component    carrier
# StorageUnit  Reservoir & Dam       7.686043e+06
# Link         H2 electrolysis      -8.672736e+05
#              battery charger      -3.025354e+06
#              H2 fuel cell          4.024149e+05
#              battery discharger    2.450536e+06
# Load         -                    -1.965415e+07
# Generator    Offshore Wind (DC)    2.986375e-02
#              Onshore Wind          2.913540e+05
#              Run of River          1.401528e+06
#              Solar                 1.131490e+07
# dtype: float64

# %%
n.statistics.energy_balance()
# Out:
# component    carrier             bus_carrier
# StorageUnit  Reservoir & Dam     AC             7.686043e+06
# Link         H2 electrolysis     AC            -8.672736e+05
#              H2 fuel cell        H2            -6.938188e+05
#              battery charger     AC            -3.025354e+06
#              battery discharger  battery       -2.722818e+06
#              H2 electrolysis     H2             6.938188e+05
#              H2 fuel cell        AC             4.024149e+05
#              battery charger     battery        2.722818e+06
#              battery discharger  AC             2.450536e+06
# Store        Battery Storage     battery       -1.818350e-10
#              Hydrogen Storage    H2            -1.624372e-10
# Load         -                   AC            -1.965415e+07
# Generator    Offshore Wind (DC)  AC             2.986375e-02
#              Onshore Wind        AC             2.913540e+05
#              Run of River        AC             1.401528e+06
#              Solar               AC             1.131490e+07
# dtype: float64

# %%
energy_balance = n.statistics.energy_balance().loc[:, :, "AC"].groupby("carrier").sum().div(1e6).to_frame().T
print(energy_balance)
# Out:
# carrier          -  H2 electrolysis  H2 fuel cell  Offshore Wind (DC)  \
# 0       -19.654152        -0.867274      0.402415        2.986375e-08
#
# carrier  Onshore Wind  Reservoir & Dam  Run of River      Solar  \
# 0            0.291354         7.686043      1.401528  11.314903
#
# carrier  battery charger  battery discharger
# 0              -3.025354            2.450536

# %%
n.statistics.supply().plot.bar()
# Out:
# WARNING:pypsa.statistics:Network has multiple bus carriers which are aggregated together. To separate bus carriers set `bus_carrier` or use groupers like `get_carrier_and_bus_carrier`.
# <AxesSubplot:xlabel='component,carrier'>

# %%
(n.statistics.dispatch() / 1e6).plot.bar()
# Out:
# /tmp/ipykernel_18353/968957247.py:1: DeprecatedWarning: dispatch is deprecated as of 0.28 and will be removed in 0.29. Use 'energy_balance' instead.
#   (n.statistics.dispatch() / 1e6).plot.bar()
# WARNING:pypsa.statistics:Network has multiple bus carriers which are aggregated together. To separate bus carriers set `bus_carrier` or use groupers like `get_carrier_and_bus_carrier`.
# <AxesSubplot:xlabel='component,carrier'>
